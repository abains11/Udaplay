# %% [markdown]
# # [STARTER] Exercise - Build a Web-Aware Agent with Search and Knowledge Comparison
#
# In this exercise, you'll build an agent that can search the web for current information and compare
# it with its internal knowledge. This demonstrates how to enhance an LLM's capabilities with real-time
# web data and how to critically analyze differences between sources.

# %% [markdown]
# ## Challenge
#
# Your task is to create an agent that can:
#
# - Implement web search functionality using Tavily API
# - Parse and process search results effectively
# - Handle different types of queries (news, facts, events)
# - Extract relevant information from search results

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
import os
from datetime import datetime
from typing import List, Dict
from dotenv import load_dotenv
from tavily import TavilyClient

from lib.agents import Agent
from lib.messages import BaseMessage
from lib.tooling import tool

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Play with Tavily

# %%
api_key = os.getenv("TAVILY_API_KEY")
client = TavilyClient(api_key=api_key)

# %%
# [TODO] Define a query and run
query = ""
result = client.search(query)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[4], line 3
#       1 # [TODO] Define a query and run
#       2 query = ""
# ----> 3 result = client.search(query)
#
# File /opt/venv/lib/python3.13/site-packages/tavily/tavily.py:118, in TavilyClient.search(self, query, search_depth, topic, time_range, days, max_results, include_domains, exclude_domains, include_answer, include_raw_content, include_images, timeout, **kwargs)
#     114 """
#     115 Combined search method.
#     116 """
#     117 timeout = min(timeout, 120)
# --> 118 response_dict = self._search(query,
#     119                              search_depth=search_depth,
#     120                              topic=topic,
#     121                              time_range=time_range,
#     122                              days=days,
#     123                              max_results=max_results,
#     124                              include_domains=include_domains,
#     125                              exclude_domains=exclude_domains,
#     126                              include_answer=include_answer,
#     127                              include_raw_content=include_raw_content,
#     128                              include_images=include_images,
#     129                              timeout=timeout,
#     130                              **kwargs,
#     131                              )
#     133 tavily_results = response_dict.get("results", [])
#     135 response_dict["results"] = tavily_results
#
# File /opt/venv/lib/python3.13/site-packages/tavily/tavily.py:94, in TavilyClient._search(self, query, search_depth, topic, time_range, days, max_results, include_domains, exclude_domains, include_answer, include_raw_content, include_images, timeout, **kwargs)
#      92     raise InvalidAPIKeyError(detail)
#      93 elif response.status_code == 400:
# ---> 94     raise BadRequestError(detail)
#      95 else:
#      96     raise response.raise_for_status()
#
# BadRequestError: Query is missing.

# %%
result

# %% [markdown]
# ## Define Web Search tool

# %%
# [TODO] Define the search tool
@tool
def web_search(query: str) -> Dict:
    return

# %%
tools = [web_search]

# %% [markdown]
# ## Define Agents

# %% [markdown]
# The first agent should not use tools, just its own knowledge. The second one should have web search tool enabled.

# %%
# [TODO] Agent with no tools
simple_agent = Agent()

# %%
# [TODO] Agent with web search tool
web_agent = Agent()

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages:
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %% [markdown]
# ## Run your Agents

# %% [markdown]
# Run the Agents and compare them. The following queries are just for reference. Change them as you want.

# %% [markdown]
# **Simple Agent**
#
# **Note**: This example relies on the date being recent enough that the answer will not be in the model's training data. Try with other current events/dates if needed to get similar results.

# %%
run1 = simple_agent.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
)

print("\nMessages from run 1:")
messages = run1.get_final_state()["messages"]
print_messages(messages)

# %%
print(run1.get_final_state()["messages"][-1].content)

# %%
run2 = simple_agent.invoke(
    query="What are the most recent developments in AI technology?", 
)
print("\nMessages from run 2:")
messages = run2.get_final_state()["messages"]
print_messages(messages)

# %%
print(run2.get_final_state()["messages"][-1].content)

# %% [markdown]
# **Web Agent**

# %%
run1 = web_agent.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
)

print("\nMessages from run 1:")
messages = run1.get_final_state()["messages"]
print_messages(messages)

# %%
print(run1.get_final_state()["messages"][-1].content)

# %%
run2 = web_agent.invoke(
    query="What are the most recent developments in AI technology?", 
)
print("\nMessages from run 2:")
messages = run2.get_final_state()["messages"]
print_messages(messages)

# %%
print(run2.get_final_state()["messages"][-1].content)

# %% [markdown]
# ## Advanced

# %% [markdown]
# You can modify `agents.py` to include:
# - a comparison field in the state schema
# - a web search step
# - a comparison step in the workflow
