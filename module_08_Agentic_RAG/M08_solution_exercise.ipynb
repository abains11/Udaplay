# %% [markdown]
# # [SOLUTION] Exercise - Building an Agentic RAG System
#
# In this exercise, you will build an Agentic RAG (Retrieval-Augmented Generation) system that
# combines the power of AI agents with traditional RAG pipelines. You'll create an agent that
# can decide when and how to retrieve information from different sources, including vector
# databases, web search, and other tools.

# %% [markdown]
# ## Challenge
#
# Your challenge is to create an Agentic RAG system that can:
#
# - Build a RAG pipeline as a tool that can be used by the agent
# - Create an agent that can decide which tool to use based on the query
# - Handle different types of queries intelligently
# - Combine information from multiple sources when needed

# %% [markdown]
# ## Setup
# First, let's import the necessary libraries:

# %%
# Only needed for Udacity workspace

import importlib.util
import sys

# Check if 'pysqlite3' is available before importing
if importlib.util.find_spec("pysqlite3") is not None:
    import pysqlite3
    sys.modules['sqlite3'] = sys.modules.pop('pysqlite3')

# %%
import os
from typing import List
from dotenv import load_dotenv

from lib.agents import Agent
from lib.llm import LLM
from lib.state_machine import Run
from lib.messages import BaseMessage
from lib.tooling import tool
from lib.vector_db import VectorStoreManager, CorpusLoaderService
from lib.rag import RAG

# %%
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ## Load data to Vector DB

# %%
db = VectorStoreManager(OPENAI_API_KEY)
db
# Out:
# VectorStoreManager():<chromadb.api.client.Client object at 0x7c497496f620>

# %%
loader_service = CorpusLoaderService(db)

# %%
rag_llm = LLM(
    model="gpt-4o-mini",
    temperature=0.3,
)

# %%
games_market_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(
        store_name="games_market",
        pdf_path="TheGamingIndustry2024.pdf",
    )
)
# Out:
# VectorStore `games_market` ready!
# Pages from `TheGamingIndustry2024.pdf` added!

# %%
result:Run = games_market_rag.invoke("What's the  state of virtual reality")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# The state of virtual reality (VR) in 2024 is characterized by significant advancements and growing integration within the gaming industry. VR technology allows gamers to immerse themselves in expansive digital worlds, offering interactive and realistic experiences that transcend traditional gaming boundaries. Games like "Half-Life: Alyx" exemplify this trend by providing high-fidelity graphics, intuitive controls, and immersive audio, which enhance player engagement. Additionally, VR is being utilized beyond entertainment, with applications in education, therapy, and mental health, indicating its transformative potential in various sectors. Overall, VR is becoming a crucial component of the evolving gaming landscape, contributing to its growth and the enhancement of user experiences.

# %%
electric_vehicles_rag = RAG(
    llm=rag_llm,
    vector_store = loader_service.load_pdf(
        store_name="electric_vehicles",
        pdf_path="GlobalEVOutlook2025.pdf",
    )
)
# Out:
# VectorStore `electric_vehicles` ready!
# Pages from `GlobalEVOutlook2025.pdf` added!

# %%
result:Run = electric_vehicles_rag.invoke("What was the number of electric car sales and their market share in Brazil in 2024?")
print(result.get_final_state()["answer"])
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# In 2024, Brazil had nearly 125,000 electric car sales, which represented a market share of 6.5%.

# %% [markdown]
# ## Tools
#
# In a simple form, Agentic RAG can act like a router, choosing between multiple external sources to retrieve relevant information. These sources aren't limited to databases, they can also include tools like web search or APIs for services such as Slack or email.
#
# In this case it will choose between two collections.

# %%
@tool
def search_global_ev_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: Global EV Outlook 2025
    Publisher: International Energy Agency
    Release: May 2025
    ```
        The Global EV Outlook is an annual publication that reports on recent
        developments in electric mobility around the world. It is developed with the support
        of members of the Electric Vehicles Initiative (EVI).
    ```

    args:
        query (str): Search query
    """
    result:Run = electric_vehicles_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
@tool
def search_games_market_report_collection(query):
    """
    Search the vector database for relevant information.
    
    Source: The Gaming Industry in 2024 - Trends, Technologies & Predictions
    Publisher: Ixie Gaming
    Release: 2024
    ```
        The gaming industry, on the brink of transformative change due to technological
        advancements, is redefining entertainment and social interaction with
        immersive, personalized, and interactive experiences.
    ```

    args:
        query (str): Search query
    """
    result:Run = games_market_rag.invoke(query)
    return result.get_final_state()["answer"]

# %%
agentic_rag = Agent(
    model_name="gpt-4o-mini",
    tools=[search_global_ev_collection, search_games_market_report_collection],
    instructions=(
        "You are an Agentic RAG assistant that can intelligently decide which tools to use "
        "to answer user questions. Reason about about the response, change the query and call the tool again if needed "
        "in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers."
    )
)

# %%
def print_messages(messages: List[BaseMessage]):
    for m in messages: 
        print(f" -> (role = {m.role}, content = {m.content}, tool_calls = {getattr(m, 'tool_calls', None)})")

# %%
run_1 = agentic_rag.invoke(
    query="Who won the 2025 Oscar for International Movie?", 
    session_id="oscar",
)

print("\nMessages from run 1:")
messages = run_1.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 1:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Who won the 2025 Oscar for International Movie?, tool_calls = None)
#  -> (role = assistant, content = I currently don’t have access to real-time information or updates beyond my last training cut-off in October 2023. Therefore, I can't provide the winner of the 2025 Oscar for International Movie.
#
# You may want to check the latest news or an official Oscar-related website for the most accurate and timely information regarding the winners., tool_calls = None)

# %%
run_2 = agentic_rag.invoke(
    query= (
        "Which two countries accounted for most of the electric car exports from " 
        "the Asia Pacific region (excluding China) in 2024?"
    ),
    session_id="electric_car",
)

print("\nMessages from run 2:")
messages = run_2.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 2:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = Which two countries accounted for most of the electric car exports from the Asia Pacific region (excluding China) in 2024?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_aEbtKgJ8kzdN62kVg4rjNnZz', function=Function(arguments='{"query":"electric car exports Asia Pacific region excluding China 2024"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_mCkBn7jE4mINQ1vB2QgYk5TX', function=Function(arguments='{"query":"electric vehicle exports 2024 Asia Pacific countries"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, several Asia Pacific countries, including Thailand, the Philippines, Vietnam, and Singapore, are implementing policies to support electric vehicle (EV) adoption, such as reducing import duties and providing purchase subsidies. Thailand is particularly focused on establishing new incentives for battery electric vehicle (BEV) manufacturers. The outlook for EV sales in Southeast Asia is positive, with projections indicating that electric car sales could reach 25% of total car sales by 2030. Additionally, Chinese OEMs are expected to significantly increase their manufacturing capacity in Southeast Asia, with policies favoring domestic production contributing to this growth.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_BjamftDXWCcOu313VIDrA10W', function=Function(arguments='{"query":"electric vehicle exports Thailand Philippines Vietnam Singapore 2024"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, Thailand, the Philippines, Vietnam, and Singapore are all implementing policies to support the adoption of electric vehicles (EVs). Thailand is continuing its EV 3.0 Policy, which includes purchase subsidies and tax exemptions for EVs, while the Philippines, Vietnam, and Singapore are reducing import duties and exempting EVs from excise taxes. The outlook for EV sales in Southeast Asia is positive, with expectations that electric car sales could reach 25% of total car sales by 2030. \n\nVietnam's VinFast has begun exporting electric vehicles to several countries, including Southeast Asian nations, and plans to expand its production capacity. Overall, the region is emerging as a manufacturing hub for EVs, with significant growth anticipated in the coming years.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_gNMf9cr7iBVVqsUBij8AOtMa', function=Function(arguments='{"query": "electric car exports Thailand 2024"}', name='search_global_ev_collection'), type='function'), ChatCompletionMessageToolCall(id='call_aovNUmnxhdqDGEVBM8C7Wlyy', function=Function(arguments='{"query": "electric car exports Philippines 2024"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, electric car exports to Thailand are significantly influenced by Chinese manufacturers, who account for 85% of electric car sales in the country. However, this share is expected to decline due to changes in the EV 3.5 program, which will reintroduce import taxes on electric cars by the end of 2025 and gradually phase out existing subsidies for imported vehicles. To maintain eligibility for these exemptions and subsidies, manufacturers must commit to producing a certain number of battery electric vehicles domestically by the end of 2026.", tool_calls = None)
#  -> (role = tool, content = "I don't know.", tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_DgA44DyQmG5RshiC831RksLp', function=Function(arguments='{"query":"Vietnam electric vehicle exports 2024"}', name='search_global_ev_collection'), type='function')])
#  -> (role = tool, content = "In 2024, Vietnam's electric vehicle exports saw significant growth, particularly with VinFast exporting to 11 different countries. The largest shares of these exports went to Southeast Asian nations, specifically Indonesia (44%) and Malaysia (22%), as well as to the United States (22%). Additionally, local brands contributed to a near doubling of the electric sales share in Vietnam, reaching 17%.", tool_calls = None)
#  -> (role = assistant, content = In 2024, the two countries that accounted for most of the electric car exports from the Asia Pacific region (excluding China) were Thailand and Vietnam.
#
# 1. **Thailand**: The country has been a significant player in the electric vehicle market, although the majority of its electric car sales were influenced by Chinese manufacturers. The Thai government has been implementing policies to support EV adoption, including incentives for battery electric vehicle manufacturers.
#
# 2. **Vietnam**: Vietnam's growth in electric vehicle exports was notable, with VinFast exporting to various countries, including significant shares to Indonesia (44%) and Malaysia (22%). This expansion in exports indicates Vietnam's emerging role as a key contributor to electric vehicle exports in the region.
#
# These developments reflect the increasing focus on electric mobility in the Asia Pacific region, with both Thailand and Vietnam actively participating in the global electric vehicle market., tool_calls = None)

# %%
run_3 = agentic_rag.invoke(
    query= (
        "How games are revolutionizing education?"
    ),
    session_id="games",
)

print("\nMessages from run 3:")
messages = run_3.get_final_state()["messages"]
print_messages(messages)
# Out:
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: message_prep
# [StateMachine] Executing step: llm_processor
# [StateMachine] Starting: __entry__
# [StateMachine] Executing step: retrieve
# [StateMachine] Executing step: augment
# [StateMachine] Executing step: generate
# [StateMachine] Terminating: __termination__
# [StateMachine] Executing step: tool_executor
# [StateMachine] Executing step: llm_processor
# [StateMachine] Terminating: __termination__
#
# Messages from run 3:
#  -> (role = system, content = You are an Agentic RAG assistant that can intelligently decide which tools to use to answer user questions. Reason about about the response, change the query and call the tool again if needed in order to get better results. Always explain your reasoning for tool selection and provide comprehensive answers., tool_calls = None)
#  -> (role = user, content = How games are revolutionizing education?, tool_calls = None)
#  -> (role = assistant, content = None, tool_calls = [ChatCompletionMessageToolCall(id='call_Iph9fBbLMH5nHH2gIDAJA8Dl', function=Function(arguments='{"query":"games revolutionizing education"}', name='search_games_market_report_collection'), type='function')])
#  -> (role = tool, content = "Games are revolutionizing education by transforming the way subjects are taught through various innovative methods. Educational games enhance learning by making it more effective and engaging. For instance, simulation games and strategy games can improve critical thinking abilities, while gamification techniques are used to boost student motivation and engagement. Additionally, virtual reality (VR) is being leveraged in classrooms to provide immersive learning experiences. Overall, these advancements in gaming are reshaping educational practices and enhancing the learning process.", tool_calls = None)
#  -> (role = assistant, content = Games are revolutionizing education by implementing innovative methods that transform traditional teaching approaches. Here are some key ways in which this is happening:
#
# 1. **Enhanced Engagement**: Educational games make learning more engaging, allowing students to interact with the material in a fun and stimulating way. This keeps students motivated and more likely to participate in their learning.
#
# 2. **Critical Thinking and Problem-Solving**: Simulation and strategy games foster critical thinking skills by challenging students to solve complex problems and make decisions, which can translate to real-world applications.
#
# 3. **Gamification**: Techniques from game design, such as rewards, challenges, and levels, are being integrated into educational settings. This approach helps to boost student motivation and engagement by creating a sense of achievement and progression.
#
# 4. **Immersive Learning with Virtual Reality (VR)**: VR technology is being utilized in classrooms to provide immersive learning experiences that can enhance understanding and retention of material. For example, students can explore historical events or scientific phenomena in a virtual environment.
#
# Overall, the integration of gaming into education is reshaping teaching methods and enhancing the overall learning experience for students., tool_calls = None)
